# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import time
from selenium import webdriver
from wordcloud import WordCloud, STOPWORDS
from IPython.display import Image
import matplotlib.pyplot as plt
from pyvirtualdisplay import Display
search = input("Enter topic: ")
search = search.replace(" ","_")
link = f"https://en.wikipedia.org/wiki/{search}"
html = urlopen(link).read()
soup = BeautifulSoup(html, 'html.parser')
topic = soup.find("h1",class_="firstHeading")
print(topic.text)
full=""
for content in soup.find_all("div",class_="mw-parser-output"):
    for k in content.find_all("p"):
        full = k.text + full
    
text = full
stopwords = STOPWORDS
wc = WordCloud(
    background_color = 'white',
    stopwords = stopwords,
    height = 600,
    width = 400,       
)
wc.generate(text)
plt.figure(figsize=(10,10))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# Enter topic: tata motors
# Tata Motors
